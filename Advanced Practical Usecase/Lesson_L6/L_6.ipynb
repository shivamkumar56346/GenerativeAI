# %% [markdown]
# # L6: Building Your Crew for Production

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>. For more help, please see the <em>"Appendix - Tips and Help"</em> Lesson.</p>

# %% [markdown]
# ## Creating a new project

# %%
! crewai create crew new_project --provider openai
# Out:
# Creating folder new_project...
#   - Created new_project/.gitignore
#   - Created new_project/pyproject.toml
#   - Created new_project/README.md
#   - Created new_project/src/new_project/__init__.py
#   - Created new_project/src/new_project/main.py
#   - Created new_project/src/new_project/crew.py
#   - Created new_project/src/new_project/tools/custom_tool.py
#   - Created new_project/src/new_project/tools/__init__.py
#   - Created new_project/src/new_project/config/agents.yaml
#   - Created new_project/src/new_project/config/tasks.yaml
# Crew new_project created successfully!

# %% [markdown]
# ## Setting up the Environment

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note</code>:</b> The following line might take a few minutes to finish.</p>

# %%
! cd new_project && crewai install
# Out:
# Using CPython 3.11.9 interpreter at: /usr/local/bin/python
# Creating virtual environment at: .venv
# Resolved 211 packages in 1.91s
# Building new-project @ file:///home/jovyan/work/L13/new_project
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# crewai     ------------------------------ 14.86 KiB/370.29 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# crewai     ------------------------------ 14.86 KiB/370.29 KiB
# grpcio     ------------------------------     0 B/5.93 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# crewai     ------------------------------ 14.86 KiB/370.29 KiB
# cryptography ------------------------------     0 B/4.25 MiB
# grpcio     ------------------------------     0 B/5.93 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# crewai     ------------------------------ 14.86 KiB/370.29 KiB
# hf-xet     ------------------------------     0 B/3.04 MiB
# cryptography ------------------------------     0 B/4.25 MiB
# grpcio     ------------------------------     0 B/5.93 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# crewai     ------------------------------ 14.86 KiB/370.29 KiB
# pydantic-core ------------------------------     0 B/1.91 MiB
# hf-xet     ------------------------------     0 B/3.04 MiB
# cryptography ------------------------------     0 B/4.25 MiB
# grpcio     ------------------------------     0 B/5.93 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# crewai     ------------------------------ 14.86 KiB/370.29 KiB
# kubernetes ------------------------------     0 B/1.85 MiB
# pydantic-core ------------------------------     0 B/1.91 MiB
# hf-xet     ------------------------------     0 B/3.04 MiB
# cryptography ------------------------------     0 B/4.25 MiB
# grpcio     ------------------------------     0 B/5.93 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# crewai     ------------------------------ 14.86 KiB/370.29 KiB
# aiohttp    ------------------------------     0 B/1.65 MiB
# kubernetes ------------------------------     0 B/1.85 MiB
# pydantic-core ------------------------------     0 B/1.91 MiB
# hf-xet     ------------------------------     0 B/3.04 MiB
# cryptography ------------------------------     0 B/4.25 MiB
# grpcio     ------------------------------     0 B/5.93 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# crewai     ------------------------------ 14.86 KiB/370.29 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# aiohttp    ------------------------------     0 B/1.65 MiB
# kubernetes ------------------------------     0 B/1.85 MiB
# pydantic-core ------------------------------     0 B/1.91 MiB
# hf-xet     ------------------------------     0 B/3.04 MiB
# cryptography ------------------------------     0 B/4.25 MiB
# grpcio     ------------------------------     0 B/5.93 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# crewai     ------------------------------ 14.86 KiB/370.29 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# aiohttp    ------------------------------     0 B/1.65 MiB
# kubernetes ------------------------------     0 B/1.85 MiB
# pydantic-core ------------------------------     0 B/1.91 MiB
# hf-xet     ------------------------------     0 B/3.04 MiB
# cryptography ------------------------------     0 B/4.25 MiB
# grpcio     ------------------------------     0 B/5.93 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# crewai     ------------------------------ 14.86 KiB/370.29 KiB
# greenlet   ------------------------------     0 B/573.91 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# aiohttp    ------------------------------     0 B/1.65 MiB
# kubernetes ------------------------------     0 B/1.85 MiB
# pydantic-core ------------------------------     0 B/1.91 MiB
# hf-xet     ------------------------------     0 B/3.04 MiB
# cryptography ------------------------------     0 B/4.25 MiB
# grpcio     ------------------------------     0 B/5.93 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# crewai     ------------------------------ 14.86 KiB/370.29 KiB
# pytz       ------------------------------     0 B/497.29 KiB
# greenlet   ------------------------------     0 B/573.91 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# aiohttp    ------------------------------     0 B/1.65 MiB
# kubernetes ------------------------------     0 B/1.85 MiB
# pydantic-core ------------------------------     0 B/1.91 MiB
# hf-xet     ------------------------------     0 B/3.04 MiB
# cryptography ------------------------------     0 B/4.25 MiB
# grpcio     ------------------------------     0 B/5.93 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# crewai     ------------------------------ 14.86 KiB/370.29 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# pytz       ------------------------------     0 B/497.29 KiB
# greenlet   ------------------------------     0 B/573.91 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# aiohttp    ------------------------------     0 B/1.65 MiB
# kubernetes ------------------------------     0 B/1.85 MiB
# pydantic-core ------------------------------     0 B/1.91 MiB
# hf-xet     ------------------------------     0 B/3.04 MiB
# cryptography ------------------------------     0 B/4.25 MiB
# grpcio     ------------------------------     0 B/5.93 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# crewai     ------------------------------ 14.86 KiB/370.29 KiB
# watchfiles ------------------------------     0 B/442.52 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# pytz       ------------------------------     0 B/497.29 KiB
# greenlet   ------------------------------     0 B/573.91 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# aiohttp    ------------------------------     0 B/1.65 MiB
# kubernetes ------------------------------     0 B/1.85 MiB
# pydantic-core ------------------------------     0 B/1.91 MiB
# hf-xet     ------------------------------     0 B/3.04 MiB
# cryptography ------------------------------     0 B/4.25 MiB
# grpcio     ------------------------------     0 B/5.93 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# crewai     ------------------------------ 14.86 KiB/370.29 KiB
# pydantic   ------------------------------     0 B/434.36 KiB
# watchfiles ------------------------------     0 B/442.52 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# pytz       ------------------------------     0 B/497.29 KiB
# greenlet   ------------------------------     0 B/573.91 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# aiohttp    ------------------------------     0 B/1.65 MiB
# kubernetes ------------------------------     0 B/1.85 MiB
# pydantic-core ------------------------------     0 B/1.91 MiB
# hf-xet     ------------------------------     0 B/3.04 MiB
# cryptography ------------------------------     0 B/4.25 MiB
# grpcio     ------------------------------     0 B/5.93 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# crewai     ------------------------------ 46.86 KiB/370.29 KiB
# rpds-py    ------------------------------ 14.92 KiB/374.67 KiB
# prompt-toolkit ------------------------------ 30.88 KiB/378.72 KiB
# langchain-core ------------------------------ 14.88 KiB/433.06 KiB
# pydantic   ------------------------------ 30.88 KiB/434.36 KiB
# watchfiles ------------------------------ 14.91 KiB/442.52 KiB
# httptools  ------------------------------ 8.66 KiB/449.01 KiB
# cffi       ------------------------------ 30.88 KiB/456.29 KiB
# pytz       ------------------------------ 25.97 KiB/497.29 KiB
# mpmath     ------------------------------ 16.00 KiB/523.63 KiB
# huggingface-hub ------------------------------ 30.88 KiB/548.29 KiB
# greenlet   ------------------------------ 30.88 KiB/573.91 KiB
# chromadb   ------------------------------ 14.92 KiB/613.62 KiB
# crewai-tools ------------------------------ 14.88 KiB/661.14 KiB
# pyvis      ------------------------------ 14.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 30.88 KiB/745.07 KiB
# openai     ------------------------------ 30.89 KiB/768.38 KiB
# regex      ------------------------------ 23.55 KiB/780.14 KiB
# ipython    ------------------------------ 16.00 KiB/812.37 KiB
# langchain  ------------------------------ 14.88 KiB/994.33 KiB
# tiktoken   ------------------------------ 7.67 KiB/1.13 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# crewai     ------------------------------ 62.86 KiB/370.29 KiB
# rpds-py    ------------------------------ 157.74 KiB/374.67 KiB
# prompt-toolkit ------------------------------ 62.88 KiB/378.72 KiB
# langchain-core ------------------------------ 14.88 KiB/433.06 KiB
# pydantic   ------------------------------ 62.88 KiB/434.36 KiB
# watchfiles ------------------------------ 141.97 KiB/442.52 KiB
# httptools  ------------------------------ 8.66 KiB/449.01 KiB
# cffi       ------------------------------ 142.34 KiB/456.29 KiB
# pytz       ------------------------------ 41.97 KiB/497.29 KiB
# mpmath     ------------------------------ 128.00 KiB/523.63 KiB
# huggingface-hub ------------------------------ 62.88 KiB/548.29 KiB
# greenlet   ------------------------------ 155.93 KiB/573.91 KiB
# chromadb   ------------------------------ 30.92 KiB/613.62 KiB
# crewai-tools ------------------------------ 14.88 KiB/661.14 KiB
# pyvis      ------------------------------ 46.74 KiB/738.32 KiB
# pyyaml     ------------------------------ 46.88 KiB/745.07 KiB
# openai     ------------------------------ 46.89 KiB/768.38 KiB
# regex      ------------------------------ 110.92 KiB/780.14 KiB
# ipython    ------------------------------ 32.00 KiB/812.37 KiB
# langchain  ------------------------------ 14.88 KiB/994.33 KiB
# tiktoken   ------------------------------ 142.92 KiB/1.13 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# crewai     ------------------------------ 62.86 KiB/370.29 KiB
# rpds-py    ------------------------------ 206.58 KiB/374.67 KiB
# prompt-toolkit ------------------------------ 91.85 KiB/378.72 KiB
# langchain-core ------------------------------ 46.88 KiB/433.06 KiB
# pydantic   ------------------------------ 138.75 KiB/434.36 KiB
# watchfiles ------------------------------ 237.97 KiB/442.52 KiB
# httptools  ------------------------------ 207.53 KiB/449.01 KiB
# cffi       ------------------------------ 222.34 KiB/456.29 KiB
# pytz       ------------------------------ 41.97 KiB/497.29 KiB
# mpmath     ------------------------------ 192.00 KiB/523.63 KiB
# huggingface-hub ------------------------------ 110.29 KiB/548.29 KiB
# greenlet   ------------------------------ 235.93 KiB/573.91 KiB
# chromadb   ------------------------------ 62.92 KiB/613.62 KiB
# crewai-tools ------------------------------ 30.88 KiB/661.14 KiB
# pyvis      ------------------------------ 221.89 KiB/738.32 KiB
# pyyaml     ------------------------------ 238.60 KiB/745.07 KiB
# openai     ------------------------------ 62.89 KiB/768.38 KiB
# regex      ------------------------------ 206.92 KiB/780.14 KiB
# ipython    ------------------------------ 95.50 KiB/812.37 KiB
# langchain  ------------------------------ 30.88 KiB/994.33 KiB
# tiktoken   ------------------------------ 222.92 KiB/1.13 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# crewai     ------------------------------ 78.86 KiB/370.29 KiB
# rpds-py    ------------------------------ 285.85 KiB/374.67 KiB
# prompt-toolkit ------------------------------ 91.85 KiB/378.72 KiB
# langchain-core ------------------------------ 62.88 KiB/433.06 KiB
# pydantic   ------------------------------ 190.22 KiB/434.36 KiB
# watchfiles ------------------------------ 317.97 KiB/442.52 KiB
# httptools  ------------------------------ 270.91 KiB/449.01 KiB
# cffi       ------------------------------ 302.34 KiB/456.29 KiB
# pytz       ------------------------------ 57.87 KiB/497.29 KiB
# mpmath     ------------------------------ 272.00 KiB/523.63 KiB
# huggingface-hub ------------------------------ 254.40 KiB/548.29 KiB
# greenlet   ------------------------------ 303.93 KiB/573.91 KiB
# chromadb   ------------------------------ 78.92 KiB/613.62 KiB
# crewai-tools ------------------------------ 30.88 KiB/661.14 KiB
# pyvis      ------------------------------ 286.00 KiB/738.32 KiB
# pyyaml     ------------------------------ 302.60 KiB/745.07 KiB
# openai     ------------------------------ 77.16 KiB/768.38 KiB
# regex      ------------------------------ 270.92 KiB/780.14 KiB
# ipython    ------------------------------ 191.50 KiB/812.37 KiB
# langchain  ------------------------------ 46.88 KiB/994.33 KiB
# tiktoken   ------------------------------ 270.92 KiB/1.13 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/204)
# crewai     ------------------------------ 106.82 KiB/370.29 KiB
# rpds-py    ------------------------------ 349.85 KiB/374.67 KiB
# prompt-toolkit ------------------------------ 123.85 KiB/378.72 KiB
# langchain-core ------------------------------ 78.88 KiB/433.06 KiB
# pydantic   ------------------------------ 254.11 KiB/434.36 KiB
# watchfiles ------------------------------ 358.51 KiB/442.52 KiB
# httptools  ------------------------------ 318.91 KiB/449.01 KiB
# cffi       ------------------------------ 366.34 KiB/456.29 KiB
# pytz       ------------------------------ 109.51 KiB/497.29 KiB
# mpmath     ------------------------------ 368.00 KiB/523.63 KiB
# huggingface-hub ------------------------------ 286.40 KiB/548.29 KiB
# greenlet   ------------------------------ 367.93 KiB/573.91 KiB
# chromadb   ------------------------------ 333.95 KiB/613.62 KiB
# crewai-tools ------------------------------ 46.88 KiB/661.14 KiB
# pyvis      ------------------------------ 350.00 KiB/738.32 KiB
# pyyaml     ------------------------------ 366.60 KiB/745.07 KiB
# openai     ------------------------------ 93.16 KiB/768.38 KiB
# regex      ------------------------------ 334.92 KiB/780.14 KiB
# ipython    ------------------------------ 255.29 KiB/812.37 KiB
# langchain  ------------------------------ 46.88 KiB/994.33 KiB
# tiktoken   ------------------------------ 334.71 KiB/1.13 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/204)
# crewai     ------------------------------ 106.82 KiB/370.29 KiB
# prompt-toolkit ------------------------------ 123.85 KiB/378.72 KiB
# langchain-core ------------------------------ 110.88 KiB/433.06 KiB
# pydantic   ------------------------------ 286.22 KiB/434.36 KiB
# watchfiles ------------------------------ 397.81 KiB/442.52 KiB
# httptools  ------------------------------ 366.91 KiB/449.01 KiB
# cffi       ------------------------------ 382.34 KiB/456.29 KiB
# pytz       ------------------------------ 109.51 KiB/497.29 KiB
# mpmath     ------------------------------ 400.00 KiB/523.63 KiB
# huggingface-hub ------------------------------ 334.40 KiB/548.29 KiB
# greenlet   ------------------------------ 399.93 KiB/573.91 KiB
# chromadb   ------------------------------ 366.16 KiB/613.62 KiB
# crewai-tools ------------------------------ 46.88 KiB/661.14 KiB
# pyvis      ------------------------------ 382.00 KiB/738.32 KiB
# pyyaml     ------------------------------ 398.60 KiB/745.07 KiB
# openai     ------------------------------ 93.16 KiB/768.38 KiB
# regex      ------------------------------ 382.92 KiB/780.14 KiB
# ipython    ------------------------------ 304.53 KiB/812.37 KiB
# langchain  ------------------------------ 46.88 KiB/994.33 KiB
# tiktoken   ------------------------------ 350.92 KiB/1.13 MiB
# pygments   ------------------------------ 349.71 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/204)
# crewai     ------------------------------ 122.82 KiB/370.29 KiB
# prompt-toolkit ------------------------------ 139.85 KiB/378.72 KiB
# langchain-core ------------------------------ 126.88 KiB/433.06 KiB
# pydantic   ------------------------------ 286.22 KiB/434.36 KiB
# watchfiles ------------------------------ 413.97 KiB/442.52 KiB
# httptools  ------------------------------ 408.56 KiB/449.01 KiB
# cffi       ------------------------------ 414.34 KiB/456.29 KiB
# pytz       ------------------------------ 109.51 KiB/497.29 KiB
# mpmath     ------------------------------ 415.90 KiB/523.63 KiB
# huggingface-hub ------------------------------ 366.40 KiB/548.29 KiB
# greenlet   ------------------------------ 419.68 KiB/573.91 KiB
# chromadb   ------------------------------ 366.16 KiB/613.62 KiB
# crewai-tools ------------------------------ 62.88 KiB/661.14 KiB
# pyvis      ------------------------------ 414.00 KiB/738.32 KiB
# pyyaml     ------------------------------ 430.60 KiB/745.07 KiB
# openai     ------------------------------ 109.16 KiB/768.38 KiB
# regex      ------------------------------ 414.92 KiB/780.14 KiB
# ipython    ------------------------------ 335.50 KiB/812.37 KiB
# langchain  ------------------------------ 46.88 KiB/994.33 KiB
# tiktoken   ------------------------------ 398.92 KiB/1.13 MiB
# pygments   ------------------------------ 349.71 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/204)
# langsmith  ------------------------------ 16.00 KiB/354.49 KiB
# crewai     ------------------------------ 122.82 KiB/370.29 KiB
# prompt-toolkit ------------------------------ 171.85 KiB/378.72 KiB
# langchain-core ------------------------------ 158.88 KiB/433.06 KiB
# pydantic   ------------------------------ 318.22 KiB/434.36 KiB
# httptools  ------------------------------ 448.59 KiB/449.01 KiB
# cffi       ------------------------------ 456.02 KiB/456.29 KiB
# pytz       ------------------------------ 125.51 KiB/497.29 KiB
# mpmath     ------------------------------ 480.00 KiB/523.63 KiB
# huggingface-hub ------------------------------ 398.40 KiB/548.29 KiB
# greenlet   ------------------------------ 463.93 KiB/573.91 KiB
# chromadb   ------------------------------ 382.16 KiB/613.62 KiB
# crewai-tools ------------------------------ 78.88 KiB/661.14 KiB
# pyvis      ------------------------------ 447.73 KiB/738.32 KiB
# pyyaml     ------------------------------ 478.60 KiB/745.07 KiB
# openai     ------------------------------ 125.16 KiB/768.38 KiB
# regex      ------------------------------ 462.92 KiB/780.14 KiB
# ipython    ------------------------------ 367.50 KiB/812.37 KiB
# langchain  ------------------------------ 46.88 KiB/994.33 KiB
# tiktoken   ------------------------------ 444.40 KiB/1.13 MiB
# pygments   ------------------------------ 397.71 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/204)
# langsmith  ------------------------------ 32.00 KiB/354.49 KiB
# crewai     ------------------------------ 122.82 KiB/370.29 KiB
# prompt-toolkit ------------------------------ 171.85 KiB/378.72 KiB
# langchain-core ------------------------------ 158.88 KiB/433.06 KiB
# pydantic   ------------------------------ 334.22 KiB/434.36 KiB
# httptools  ------------------------------ 448.59 KiB/449.01 KiB
# pytz       ------------------------------ 125.51 KiB/497.29 KiB
# mpmath     ------------------------------ 480.00 KiB/523.63 KiB
# huggingface-hub ------------------------------ 398.40 KiB/548.29 KiB
# greenlet   ------------------------------ 463.93 KiB/573.91 KiB
# chromadb   ------------------------------ 382.16 KiB/613.62 KiB
# crewai-tools ------------------------------ 78.88 KiB/661.14 KiB
# pyvis      ------------------------------ 447.73 KiB/738.32 KiB
# pyyaml     ------------------------------ 478.60 KiB/745.07 KiB
# openai     ------------------------------ 125.16 KiB/768.38 KiB
# regex      ------------------------------ 462.92 KiB/780.14 KiB
# ipython    ------------------------------ 367.50 KiB/812.37 KiB
# langchain  ------------------------------ 46.88 KiB/994.33 KiB
# tiktoken   ------------------------------ 444.40 KiB/1.13 MiB
# pygments   ------------------------------ 397.71 KiB/1.17 MiB
# jedi       ------------------------------ 221.43 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/204)
# langsmith  ------------------------------ 32.00 KiB/354.49 KiB
# crewai     ------------------------------ 122.82 KiB/370.29 KiB
# prompt-toolkit ------------------------------ 171.85 KiB/378.72 KiB
# langchain-core ------------------------------ 174.88 KiB/433.06 KiB
# pydantic   ------------------------------ 334.22 KiB/434.36 KiB
# pytz       ------------------------------ 125.51 KiB/497.29 KiB
# mpmath     ------------------------------ 495.47 KiB/523.63 KiB
# huggingface-hub ------------------------------ 398.40 KiB/548.29 KiB
# greenlet   ------------------------------ 463.93 KiB/573.91 KiB
# chromadb   ------------------------------ 398.16 KiB/613.62 KiB
# crewai-tools ------------------------------ 78.88 KiB/661.14 KiB
# pyvis      ------------------------------ 462.00 KiB/738.32 KiB
# pyyaml     ------------------------------ 494.49 KiB/745.07 KiB
# openai     ------------------------------ 141.16 KiB/768.38 KiB
# regex      ------------------------------ 478.92 KiB/780.14 KiB
# ipython    ------------------------------ 367.50 KiB/812.37 KiB
# langchain  ------------------------------ 62.88 KiB/994.33 KiB
# tiktoken   ------------------------------ 460.40 KiB/1.13 MiB
# pygments   ------------------------------ 413.71 KiB/1.17 MiB
# jedi       ------------------------------ 221.43 KiB/1.50 MiB
# networkx   ------------------------------ 286.88 KiB/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/204)
# jiter      ------------------------------     0 B/343.92 KiB
# langsmith  ------------------------------ 32.00 KiB/354.49 KiB
# crewai     ------------------------------ 122.82 KiB/370.29 KiB
# prompt-toolkit ------------------------------ 187.20 KiB/378.72 KiB
# langchain-core ------------------------------ 174.88 KiB/433.06 KiB
# pydantic   ------------------------------ 350.22 KiB/434.36 KiB
# pytz       ------------------------------ 125.51 KiB/497.29 KiB
# mpmath     ------------------------------ 495.47 KiB/523.63 KiB
# huggingface-hub ------------------------------ 398.40 KiB/548.29 KiB
# greenlet   ------------------------------ 463.93 KiB/573.91 KiB
# chromadb   ------------------------------ 398.16 KiB/613.62 KiB
# crewai-tools ------------------------------ 78.88 KiB/661.14 KiB
# pyvis      ------------------------------ 478.00 KiB/738.32 KiB
# pyyaml     ------------------------------ 494.49 KiB/745.07 KiB
# openai     ------------------------------ 141.16 KiB/768.38 KiB
# regex      ------------------------------ 494.92 KiB/780.14 KiB
# ipython    ------------------------------ 367.50 KiB/812.37 KiB
# langchain  ------------------------------ 62.88 KiB/994.33 KiB
# tiktoken   ------------------------------ 460.40 KiB/1.13 MiB
# pygments   ------------------------------ 429.71 KiB/1.17 MiB
# jedi       ------------------------------ 237.43 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/204)
# tzdata     ------------------------------ 15.67 KiB/339.69 KiB
# yarl       ------------------------------ 41.68 KiB/340.80 KiB
# jiter      ------------------------------ 61.80 KiB/343.92 KiB
# langsmith  ------------------------------ 112.00 KiB/354.49 KiB
# crewai     ------------------------------ 138.82 KiB/370.29 KiB
# prompt-toolkit ------------------------------ 235.85 KiB/378.72 KiB
# langchain-core ------------------------------ 206.88 KiB/433.06 KiB
# pytz       ------------------------------ 125.51 KiB/497.29 KiB
# mpmath     ------------------------------ 523.63 KiB/523.63 KiB
# huggingface-hub ------------------------------ 414.40 KiB/548.29 KiB
# greenlet   ------------------------------ 479.93 KiB/573.91 KiB
# chromadb   ------------------------------ 414.16 KiB/613.62 KiB
# crewai-tools ------------------------------ 94.88 KiB/661.14 KiB
# pyvis      ------------------------------ 526.00 KiB/738.32 KiB
# pyyaml     ------------------------------ 537.36 KiB/745.07 KiB
# openai     ------------------------------ 189.16 KiB/768.38 KiB
# regex      ------------------------------ 542.92 KiB/780.14 KiB
# ipython    ------------------------------ 415.50 KiB/812.37 KiB
# langchain  ------------------------------ 62.88 KiB/994.33 KiB
# tiktoken   ------------------------------ 503.40 KiB/1.13 MiB
# pygments   ------------------------------ 477.71 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/204)
# tzdata     ------------------------------ 15.67 KiB/339.69 KiB
# yarl       ------------------------------ 57.68 KiB/340.80 KiB
# jiter      ------------------------------ 61.80 KiB/343.92 KiB
# langsmith  ------------------------------ 128.00 KiB/354.49 KiB
# crewai     ------------------------------ 138.82 KiB/370.29 KiB
# prompt-toolkit ------------------------------ 251.85 KiB/378.72 KiB
# langchain-core ------------------------------ 206.88 KiB/433.06 KiB
# pytz       ------------------------------ 125.51 KiB/497.29 KiB
# huggingface-hub ------------------------------ 430.40 KiB/548.29 KiB
# greenlet   ------------------------------ 495.93 KiB/573.91 KiB
# chromadb   ------------------------------ 414.16 KiB/613.62 KiB
# crewai-tools ------------------------------ 94.88 KiB/661.14 KiB
# pyvis      ------------------------------ 542.00 KiB/738.32 KiB
# pyyaml     ------------------------------ 537.36 KiB/745.07 KiB
# openai     ------------------------------ 189.16 KiB/768.38 KiB
# regex      ------------------------------ 558.92 KiB/780.14 KiB
# ipython    ------------------------------ 431.50 KiB/812.37 KiB
# langchain  ------------------------------ 62.88 KiB/994.33 KiB
# tiktoken   ------------------------------ 519.40 KiB/1.13 MiB
# pygments   ------------------------------ 493.71 KiB/1.17 MiB
# jedi       ------------------------------ 237.43 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/204)
# qdrant-client ------------------------------     0 B/329.42 KiB
# tzdata     ------------------------------ 15.67 KiB/339.69 KiB
# yarl       ------------------------------ 57.68 KiB/340.80 KiB
# jiter      ------------------------------ 77.80 KiB/343.92 KiB
# langsmith  ------------------------------ 144.00 KiB/354.49 KiB
# crewai     ------------------------------ 138.82 KiB/370.29 KiB
# prompt-toolkit ------------------------------ 267.85 KiB/378.72 KiB
# langchain-core ------------------------------ 219.26 KiB/433.06 KiB
# pytz       ------------------------------ 125.51 KiB/497.29 KiB
# huggingface-hub ------------------------------ 430.40 KiB/548.29 KiB
# greenlet   ------------------------------ 495.93 KiB/573.91 KiB
# chromadb   ------------------------------ 414.16 KiB/613.62 KiB
# crewai-tools ------------------------------ 110.88 KiB/661.14 KiB
# pyvis      ------------------------------ 542.00 KiB/738.32 KiB
# pyyaml     ------------------------------ 539.71 KiB/745.07 KiB
# openai     ------------------------------ 205.16 KiB/768.38 KiB
# regex      ------------------------------ 558.92 KiB/780.14 KiB
# ipython    ------------------------------ 447.50 KiB/812.37 KiB
# langchain  ------------------------------ 78.88 KiB/994.33 KiB
# tiktoken   ------------------------------ 519.40 KiB/1.13 MiB
# pygments   ------------------------------ 509.71 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (6/204)
# protobuf   ------------------------------ 75.33 KiB/314.46 KiB
# qdrant-client ------------------------------ 72.32 KiB/329.42 KiB
# tzdata     ------------------------------ 31.67 KiB/339.69 KiB
# yarl       ------------------------------ 125.76 KiB/340.80 KiB
# jiter      ------------------------------ 159.88 KiB/343.92 KiB
# langsmith  ------------------------------ 208.00 KiB/354.49 KiB
# crewai     ------------------------------ 190.75 KiB/370.29 KiB
# prompt-toolkit ------------------------------ 335.85 KiB/378.72 KiB
# langchain-core ------------------------------ 334.77 KiB/433.06 KiB
# pytz       ------------------------------ 141.51 KiB/497.29 KiB
# huggingface-hub ------------------------------ 478.40 KiB/548.29 KiB
# greenlet   ------------------------------ 559.93 KiB/573.91 KiB
# chromadb   ------------------------------ 462.06 KiB/613.62 KiB
# crewai-tools ------------------------------ 158.88 KiB/661.14 KiB
# pyvis      ------------------------------ 608.14 KiB/738.32 KiB
# pyyaml     ------------------------------ 606.60 KiB/745.07 KiB
# openai     ------------------------------ 252.84 KiB/768.38 KiB
# regex      ------------------------------ 654.92 KiB/780.14 KiB
# ipython    ------------------------------ 495.28 KiB/812.37 KiB
# langchain  ------------------------------ 110.88 KiB/994.33 KiB
# tiktoken   ------------------------------ 590.82 KiB/1.13 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (6/204)
# protobuf   ------------------------------ 75.93 KiB/314.46 KiB
# qdrant-client ------------------------------ 88.32 KiB/329.42 KiB
# tzdata     ------------------------------ 77.21 KiB/339.69 KiB
# yarl       ------------------------------ 141.76 KiB/340.80 KiB
# jiter      ------------------------------ 166.43 KiB/343.92 KiB
# langsmith  ------------------------------ 240.00 KiB/354.49 KiB
# crewai     ------------------------------ 190.75 KiB/370.29 KiB
# prompt-toolkit ------------------------------ 351.85 KiB/378.72 KiB
# langchain-core ------------------------------ 350.88 KiB/433.06 KiB
# pytz       ------------------------------ 141.51 KiB/497.29 KiB
# huggingface-hub ------------------------------ 494.40 KiB/548.29 KiB
# chromadb   ------------------------------ 478.16 KiB/613.62 KiB
# crewai-tools ------------------------------ 174.88 KiB/661.14 KiB
# pyvis      ------------------------------ 627.51 KiB/738.32 KiB
# pyyaml     ------------------------------ 609.32 KiB/745.07 KiB
# openai     ------------------------------ 268.84 KiB/768.38 KiB
# regex      ------------------------------ 670.92 KiB/780.14 KiB
# ipython    ------------------------------ 527.28 KiB/812.37 KiB
# langchain  ------------------------------ 110.88 KiB/994.33 KiB
# tiktoken   ------------------------------ 590.92 KiB/1.13 MiB
# pygments   ------------------------------ 621.71 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (6/204)
# pypdf      ------------------------------     0 B/305.85 KiB
# protobuf   ------------------------------ 107.93 KiB/314.46 KiB
# qdrant-client ------------------------------ 104.32 KiB/329.42 KiB
# tzdata     ------------------------------ 77.21 KiB/339.69 KiB
# yarl       ------------------------------ 173.76 KiB/340.80 KiB
# jiter      ------------------------------ 189.80 KiB/343.92 KiB
# langsmith  ------------------------------ 256.00 KiB/354.49 KiB
# crewai     ------------------------------ 206.75 KiB/370.29 KiB
# langchain-core ------------------------------ 382.88 KiB/433.06 KiB
# pytz       ------------------------------ 157.51 KiB/497.29 KiB
# huggingface-hub ------------------------------ 526.40 KiB/548.29 KiB
# chromadb   ------------------------------ 478.16 KiB/613.62 KiB
# crewai-tools ------------------------------ 334.88 KiB/661.14 KiB
# pyvis      ------------------------------ 654.00 KiB/738.32 KiB
# pyyaml     ------------------------------ 641.32 KiB/745.07 KiB
# openai     ------------------------------ 301.16 KiB/768.38 KiB
# regex      ------------------------------ 718.92 KiB/780.14 KiB
# ipython    ------------------------------ 575.50 KiB/812.37 KiB
# langchain  ------------------------------ 126.88 KiB/994.33 KiB
# tiktoken   ------------------------------ 622.81 KiB/1.13 MiB
# pygments   ------------------------------ 669.71 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (6/204)
# pypdf      ------------------------------ 32.00 KiB/305.85 KiB
# protobuf   ------------------------------ 139.93 KiB/314.46 KiB
# qdrant-client ------------------------------ 120.32 KiB/329.42 KiB
# tzdata     ------------------------------ 77.21 KiB/339.69 KiB
# yarl       ------------------------------ 205.76 KiB/340.80 KiB
# jiter      ------------------------------ 221.80 KiB/343.92 KiB
# langsmith  ------------------------------ 274.55 KiB/354.49 KiB
# crewai     ------------------------------ 206.75 KiB/370.29 KiB
# langchain-core ------------------------------ 382.88 KiB/433.06 KiB
# pytz       ------------------------------ 157.51 KiB/497.29 KiB
# huggingface-hub ------------------------------ 526.40 KiB/548.29 KiB
# chromadb   ------------------------------ 494.16 KiB/613.62 KiB
# crewai-tools ------------------------------ 542.88 KiB/661.14 KiB
# pyvis      ------------------------------ 679.72 KiB/738.32 KiB
# pyyaml     ------------------------------ 670.60 KiB/745.07 KiB
# openai     ------------------------------ 301.16 KiB/768.38 KiB
# regex      ------------------------------ 750.92 KiB/780.14 KiB
# ipython    ------------------------------ 591.50 KiB/812.37 KiB
# langchain  ------------------------------ 126.88 KiB/994.33 KiB
# tiktoken   ------------------------------ 654.81 KiB/1.13 MiB
# pygments   ------------------------------ 685.71 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (6/204)
# anthropic  ------------------------------     0 B/290.28 KiB
# pypdf      ------------------------------ 48.00 KiB/305.85 KiB
# protobuf   ------------------------------ 155.93 KiB/314.46 KiB
# qdrant-client ------------------------------ 120.32 KiB/329.42 KiB
# tzdata     ------------------------------ 77.21 KiB/339.69 KiB
# yarl       ------------------------------ 221.76 KiB/340.80 KiB
# jiter      ------------------------------ 237.80 KiB/343.92 KiB
# langsmith  ------------------------------ 290.55 KiB/354.49 KiB
# crewai     ------------------------------ 206.75 KiB/370.29 KiB
# langchain-core ------------------------------ 382.88 KiB/433.06 KiB
# pytz       ------------------------------ 157.51 KiB/497.29 KiB
# chromadb   ------------------------------ 494.16 KiB/613.62 KiB
# crewai-tools ------------------------------ 542.88 KiB/661.14 KiB
# pyvis      ------------------------------ 695.72 KiB/738.32 KiB
# pyyaml     ------------------------------ 686.60 KiB/745.07 KiB
# openai     ------------------------------ 301.16 KiB/768.38 KiB
# regex      ------------------------------ 750.92 KiB/780.14 KiB
# ipython    ------------------------------ 623.50 KiB/812.37 KiB
# langchain  ------------------------------ 126.88 KiB/994.33 KiB
# tiktoken   ------------------------------ 654.92 KiB/1.13 MiB
# pygments   ------------------------------ 749.71 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (6/204)
# cohere     ------------------------------     0 B/288.38 KiB
# anthropic  ------------------------------ 32.00 KiB/290.28 KiB
# pypdf      ------------------------------ 80.00 KiB/305.85 KiB
# protobuf   ------------------------------ 187.93 KiB/314.46 KiB
# qdrant-client ------------------------------ 160.00 KiB/329.42 KiB
# tzdata     ------------------------------ 93.21 KiB/339.69 KiB
# yarl       ------------------------------ 269.65 KiB/340.80 KiB
# jiter      ------------------------------ 281.86 KiB/343.92 KiB
# langsmith  ------------------------------ 320.00 KiB/354.49 KiB
# crewai     ------------------------------ 206.75 KiB/370.29 KiB
# langchain-core ------------------------------ 408.56 KiB/433.06 KiB
# pytz       ------------------------------ 173.51 KiB/497.29 KiB
# chromadb   ------------------------------ 494.16 KiB/613.62 KiB
# crewai-tools ------------------------------ 542.88 KiB/661.14 KiB
# pyvis      ------------------------------ 714.66 KiB/738.32 KiB
# pyyaml     ------------------------------ 718.60 KiB/745.07 KiB
# openai     ------------------------------ 301.16 KiB/768.38 KiB
# ipython    ------------------------------ 639.50 KiB/812.37 KiB
# langchain  ------------------------------ 142.88 KiB/994.33 KiB
# tiktoken   ------------------------------ 701.53 KiB/1.13 MiB
# pygments   ------------------------------ 797.71 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (6/204)
# cohere     ------------------------------ 16.00 KiB/288.38 KiB
# anthropic  ------------------------------ 48.00 KiB/290.28 KiB
# pypdf      ------------------------------ 112.00 KiB/305.85 KiB
# protobuf   ------------------------------ 203.93 KiB/314.46 KiB
# qdrant-client ------------------------------ 160.00 KiB/329.42 KiB
# tzdata     ------------------------------ 93.21 KiB/339.69 KiB
# yarl       ------------------------------ 269.76 KiB/340.80 KiB
# jiter      ------------------------------ 297.86 KiB/343.92 KiB
# langsmith  ------------------------------ 336.00 KiB/354.49 KiB
# crewai     ------------------------------ 211.07 KiB/370.29 KiB
# pytz       ------------------------------ 173.51 KiB/497.29 KiB
# chromadb   ------------------------------ 494.16 KiB/613.62 KiB
# crewai-tools ------------------------------ 545.25 KiB/661.14 KiB
# pyvis      ------------------------------ 718.00 KiB/738.32 KiB
# pyyaml     ------------------------------ 734.81 KiB/745.07 KiB
# openai     ------------------------------ 301.16 KiB/768.38 KiB
# ipython    ------------------------------ 639.50 KiB/812.37 KiB
# langchain  ------------------------------ 142.88 KiB/994.33 KiB
# tiktoken   ------------------------------ 717.53 KiB/1.13 MiB
# pygments   ------------------------------ 813.71 KiB/1.17 MiB
# jedi       ------------------------------ 269.43 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (6/204)
# googleapis-common-protos ------------------------------ 16.00 KiB/287.63 KiB
# cohere     ------------------------------ 32.00 KiB/288.38 KiB
# anthropic  ------------------------------ 63.19 KiB/290.28 KiB
# pypdf      ------------------------------ 128.00 KiB/305.85 KiB
# protobuf   ------------------------------ 219.93 KiB/314.46 KiB
# qdrant-client ------------------------------ 176.00 KiB/329.42 KiB
# tzdata     ------------------------------ 93.21 KiB/339.69 KiB
# yarl       ------------------------------ 285.76 KiB/340.80 KiB
# jiter      ------------------------------ 313.86 KiB/343.92 KiB
# langsmith  ------------------------------ 352.00 KiB/354.49 KiB
# crewai     ------------------------------ 227.07 KiB/370.29 KiB
# pytz       ------------------------------ 173.51 KiB/497.29 KiB
# chromadb   ------------------------------ 526.16 KiB/613.62 KiB
# crewai-tools ------------------------------ 561.25 KiB/661.14 KiB
# pyvis      ------------------------------ 734.00 KiB/738.32 KiB
# pyyaml     ------------------------------ 745.07 KiB/745.07 KiB
# openai     ------------------------------ 317.16 KiB/768.38 KiB
# ipython    ------------------------------ 654.79 KiB/812.37 KiB
# langchain  ------------------------------ 142.88 KiB/994.33 KiB
# tiktoken   ------------------------------ 718.92 KiB/1.13 MiB
# pygments   ------------------------------ 838.76 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (6/204)
# bcrypt     ------------------------------     0 B/277.50 KiB
# googleapis-common-protos ------------------------------ 16.00 KiB/287.63 KiB
# cohere     ------------------------------ 48.00 KiB/288.38 KiB
# anthropic  ------------------------------ 63.19 KiB/290.28 KiB
# pypdf      ------------------------------ 128.00 KiB/305.85 KiB
# protobuf   ------------------------------ 235.93 KiB/314.46 KiB
# qdrant-client ------------------------------ 176.00 KiB/329.42 KiB
# tzdata     ------------------------------ 93.21 KiB/339.69 KiB
# yarl       ------------------------------ 285.76 KiB/340.80 KiB
# jiter      ------------------------------ 313.86 KiB/343.92 KiB
# crewai     ------------------------------ 227.07 KiB/370.29 KiB
# pytz       ------------------------------ 173.51 KiB/497.29 KiB
# chromadb   ------------------------------ 526.16 KiB/613.62 KiB
# crewai-tools ------------------------------ 561.25 KiB/661.14 KiB
# pyvis      ------------------------------ 734.00 KiB/738.32 KiB
# pyyaml     ------------------------------ 745.07 KiB/745.07 KiB
# openai     ------------------------------ 317.16 KiB/768.38 KiB
# ipython    ------------------------------ 654.79 KiB/812.37 KiB
# langchain  ------------------------------ 142.88 KiB/994.33 KiB
# tiktoken   ------------------------------ 718.92 KiB/1.13 MiB
# pygments   ------------------------------ 854.76 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (6/204)
# bcrypt     ------------------------------     0 B/277.50 KiB
# googleapis-common-protos ------------------------------ 16.00 KiB/287.63 KiB
# cohere     ------------------------------ 48.00 KiB/288.38 KiB
# anthropic  ------------------------------ 63.19 KiB/290.28 KiB
# pypdf      ------------------------------ 128.00 KiB/305.85 KiB
# protobuf   ------------------------------ 235.93 KiB/314.46 KiB
# qdrant-client ------------------------------ 176.00 KiB/329.42 KiB
# tzdata     ------------------------------ 93.21 KiB/339.69 KiB
# yarl       ------------------------------ 301.76 KiB/340.80 KiB
# jiter      ------------------------------ 329.86 KiB/343.92 KiB
# crewai     ------------------------------ 227.07 KiB/370.29 KiB
# pytz       ------------------------------ 173.51 KiB/497.29 KiB
# chromadb   ------------------------------ 526.16 KiB/613.62 KiB
# crewai-tools ------------------------------ 561.25 KiB/661.14 KiB
# pyvis      ------------------------------ 734.00 KiB/738.32 KiB
# openai     ------------------------------ 317.16 KiB/768.38 KiB
# ipython    ------------------------------ 654.79 KiB/812.37 KiB
# langchain  ------------------------------ 142.88 KiB/994.33 KiB
# tiktoken   ------------------------------ 734.92 KiB/1.13 MiB
# pygments   ------------------------------ 854.76 KiB/1.17 MiB
# jedi       ------------------------------ 269.43 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (6/204)
# openpyxl   ------------------------------     0 B/245.03 KiB
# bcrypt     ------------------------------ 16.00 KiB/277.50 KiB
# googleapis-common-protos ------------------------------ 16.00 KiB/287.63 KiB
# cohere     ------------------------------ 48.00 KiB/288.38 KiB
# anthropic  ------------------------------ 63.19 KiB/290.28 KiB
# pypdf      ------------------------------ 160.00 KiB/305.85 KiB
# protobuf   ------------------------------ 251.93 KiB/314.46 KiB
# qdrant-client ------------------------------ 192.00 KiB/329.42 KiB
# tzdata     ------------------------------ 93.21 KiB/339.69 KiB
# yarl       ------------------------------ 317.76 KiB/340.80 KiB
# jiter      ------------------------------ 333.80 KiB/343.92 KiB
# crewai     ------------------------------ 227.07 KiB/370.29 KiB
# pytz       ------------------------------ 189.51 KiB/497.29 KiB
# chromadb   ------------------------------ 553.34 KiB/613.62 KiB
# crewai-tools ------------------------------ 561.25 KiB/661.14 KiB
# openai     ------------------------------ 317.16 KiB/768.38 KiB
# ipython    ------------------------------ 670.79 KiB/812.37 KiB
# langchain  ------------------------------ 142.88 KiB/994.33 KiB
# tiktoken   ------------------------------ 750.92 KiB/1.13 MiB
# pygments   ------------------------------ 870.76 KiB/1.17 MiB
# jedi       ------------------------------ 286.05 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (6/204)
# multidict  ------------------------------     0 B/240.93 KiB
# alembic    ------------------------------ 14.89 KiB/241.24 KiB
# openpyxl   ------------------------------ 14.88 KiB/245.03 KiB
# bcrypt     ------------------------------ 61.45 KiB/277.50 KiB
# googleapis-common-protos ------------------------------ 32.00 KiB/287.63 KiB
# cohere     ------------------------------ 48.00 KiB/288.38 KiB
# anthropic  ------------------------------ 63.19 KiB/290.28 KiB
# pypdf      ------------------------------ 182.31 KiB/305.85 KiB
# protobuf   ------------------------------ 267.93 KiB/314.46 KiB
# qdrant-client ------------------------------ 224.00 KiB/329.42 KiB
# tzdata     ------------------------------ 93.21 KiB/339.69 KiB
# yarl       ------------------------------ 340.80 KiB/340.80 KiB
# crewai     ------------------------------ 227.07 KiB/370.29 KiB
# pytz       ------------------------------ 189.51 KiB/497.29 KiB
# chromadb   ------------------------------ 553.34 KiB/613.62 KiB
# crewai-tools ------------------------------ 577.25 KiB/661.14 KiB
# openai     ------------------------------ 317.16 KiB/768.38 KiB
# ipython    ------------------------------ 670.79 KiB/812.37 KiB
# langchain  ------------------------------ 142.88 KiB/994.33 KiB
# tiktoken   ------------------------------ 782.92 KiB/1.13 MiB
# pygments   ------------------------------ 893.71 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (6/204)
# multidict  ------------------------------ 16.00 KiB/240.93 KiB
# alembic    ------------------------------ 30.89 KiB/241.24 KiB
# openpyxl   ------------------------------ 14.88 KiB/245.03 KiB
# bcrypt     ------------------------------ 77.45 KiB/277.50 KiB
# googleapis-common-protos ------------------------------ 48.00 KiB/287.63 KiB
# cohere     ------------------------------ 64.00 KiB/288.38 KiB
# anthropic  ------------------------------ 78.97 KiB/290.28 KiB
# pypdf      ------------------------------ 192.00 KiB/305.85 KiB
# protobuf   ------------------------------ 287.93 KiB/314.46 KiB
# qdrant-client ------------------------------ 240.00 KiB/329.42 KiB
# tzdata     ------------------------------ 93.21 KiB/339.69 KiB
# crewai     ------------------------------ 243.07 KiB/370.29 KiB
# pytz       ------------------------------ 189.51 KiB/497.29 KiB
# chromadb   ------------------------------ 569.34 KiB/613.62 KiB
# crewai-tools ------------------------------ 577.25 KiB/661.14 KiB
# openai     ------------------------------ 333.16 KiB/768.38 KiB
# ipython    ------------------------------ 687.50 KiB/812.37 KiB
# langchain  ------------------------------ 142.88 KiB/994.33 KiB
# tiktoken   ------------------------------ 814.92 KiB/1.13 MiB
# pygments   ------------------------------ 909.71 KiB/1.17 MiB
# jedi       ------------------------------ 286.05 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠼ Preparing packages... (15/204)
# multidict  ------------------------------ 16.00 KiB/240.93 KiB
# alembic    ------------------------------ 30.89 KiB/241.24 KiB
# openpyxl   ------------------------------ 14.88 KiB/245.03 KiB
# bcrypt     ------------------------------ 77.45 KiB/277.50 KiB
# googleapis-common-protos ------------------------------ 48.00 KiB/287.63 KiB
# cohere     ------------------------------ 64.00 KiB/288.38 KiB
# anthropic  ------------------------------ 78.97 KiB/290.28 KiB
# pypdf      ------------------------------ 192.00 KiB/305.85 KiB
# protobuf   ------------------------------ 287.93 KiB/314.46 KiB
# ...
# ⠋ Preparing packages... (198/204) 19.25 MiB/43.79 MiB
# pyright    ------------------------------ 3.68 MiB/5.42 MiB
# onnxruntime ------------------------------ 15.39 MiB/15.63 MiB
# uv         ------------------------------ 17.77 MiB/18.42 MiB
# lancedb    ------------------------------ 20.17 MiB/33.34 MiB
# pyarrow    ------------------------------ 17.26 MiB/40.84 MiB
# ⠋ Preparing packages... (198/204) 20.19 MiB/43.79 MiB
# pyright    ------------------------------ 3.68 MiB/5.42 MiB
# onnxruntime ------------------------------ 15.39 MiB/15.63 MiB
# uv         ------------------------------ 17.77 MiB/18.42 MiB
# lancedb    ------------------------------ 20.17 MiB/33.34 MiB
# pyarrow    ------------------------------ 17.30 MiB/40.84 MiB
# ⠋ Preparing packages... (198/204) 20.19 MiB/43.79 MiB
# pyright    ------------------------------ 3.68 MiB/5.42 MiB
# onnxruntime ------------------------------ 15.39 MiB/15.63 MiB
# uv         ------------------------------ 17.77 MiB/18.42 MiB
# lancedb    ------------------------------ 20.17 MiB/33.34 MiB
# pyarrow    ------------------------------ 17.31 MiB/40.84 MiB
# ⠋ Preparing packages... (198/204) 20.19 MiB/43.79 MiB
# pyright    ------------------------------ 3.68 MiB/5.42 MiB
# onnxruntime ------------------------------ 15.39 MiB/15.63 MiB
# uv         ------------------------------ 17.77 MiB/18.42 MiB
# lancedb    ------------------------------ 20.17 MiB/33.34 MiB
# pyarrow    ------------------------------ 19.17 MiB/40.84 MiB
# ⠋ Preparing packages... (198/204) 20.19 MiB/43.79 MiB
# pyright    ------------------------------ 3.68 MiB/5.42 MiB
# onnxruntime ------------------------------ 15.42 MiB/15.63 MiB
# uv         ------------------------------ 17.77 MiB/18.42 MiB
# lancedb    ------------------------------ 20.17 MiB/33.34 MiB
# pyarrow    ------------------------------ 20.10 MiB/40.84 MiB
# ⠋ Preparing packages... (198/204) 20.19 MiB/43.79 MiB
# pyright    ------------------------------ 4.12 MiB/5.42 MiB
# onnxruntime ------------------------------ 15.51 MiB/15.63 MiB
# uv         ------------------------------ 17.77 MiB/18.42 MiB
# lancedb    ------------------------------ 20.17 MiB/33.34 MiB
# pyarrow    ------------------------------ 20.38 MiB/40.84 MiB
# ⠙ Preparing packages... (198/204) 20.19 MiB/43.79 MiB
# pyright    ------------------------------ 4.25 MiB/5.42 MiB
# onnxruntime ------------------------------ 15.51 MiB/15.63 MiB
# uv         ------------------------------ 17.77 MiB/18.42 MiB
# lancedb    ------------------------------ 20.42 MiB/33.34 MiB
# pyarrow    ------------------------------ 20.38 MiB/40.84 MiB
# ⠙ Preparing packages... (198/204) 20.19 MiB/43.79 MiB
# pyright    ------------------------------ 4.25 MiB/5.42 MiB
# onnxruntime ------------------------------ 15.51 MiB/15.63 MiB
# uv         ------------------------------ 17.78 MiB/18.42 MiB
# lancedb    ------------------------------ 20.42 MiB/33.34 MiB
# pyarrow    ------------------------------ 20.38 MiB/40.84 MiB
# ⠙ Preparing packages... (198/204) 20.19 MiB/43.79 MiB
# pyright    ------------------------------ 4.25 MiB/5.42 MiB
# onnxruntime ------------------------------ 15.54 MiB/15.63 MiB
# uv         ------------------------------ 18.25 MiB/18.42 MiB
# lancedb    ------------------------------ 20.53 MiB/33.34 MiB
# pyarrow    ------------------------------ 20.38 MiB/40.84 MiB
# ⠙ Preparing packages... (198/204) 20.43 MiB/43.79 MiB
# pyright    ------------------------------ 4.25 MiB/5.42 MiB
# onnxruntime ------------------------------ 15.54 MiB/15.63 MiB
# uv         ------------------------------ 18.25 MiB/18.42 MiB
# lancedb    ------------------------------ 20.55 MiB/33.34 MiB
# pyarrow    ------------------------------ 20.38 MiB/40.84 MiB
# ⠹ Preparing packages... (198/204) 20.43 MiB/43.79 MiB
# pyright    ------------------------------ 4.25 MiB/5.42 MiB
# onnxruntime ------------------------------ 15.54 MiB/15.63 MiB
# uv         ------------------------------ 18.25 MiB/18.42 MiB
# lancedb    ------------------------------ 22.24 MiB/33.34 MiB
# pyarrow    ------------------------------ 20.38 MiB/40.84 MiB
# ⠹ Preparing packages... (198/204) 20.43 MiB/43.79 MiB
# pyright    ------------------------------ 4.25 MiB/5.42 MiB
# onnxruntime ------------------------------ 15.54 MiB/15.63 MiB
# uv         ------------------------------ 18.25 MiB/18.42 MiB
# lancedb    ------------------------------ 22.24 MiB/33.34 MiB
# pyarrow    ------------------------------ 20.41 MiB/40.84 MiB
# ⠹ Preparing packages... (198/204) 20.43 MiB/43.79 MiB
# pyright    ------------------------------ 4.25 MiB/5.42 MiB
# onnxruntime ------------------------------ 15.54 MiB/15.63 MiB
# uv         ------------------------------ 18.25 MiB/18.42 MiB
# lancedb    ------------------------------ 22.24 MiB/33.34 MiB
# pyarrow    ------------------------------ 20.44 MiB/40.84 MiB
# ⠹ Preparing packages... (198/204) 20.43 MiB/43.79 MiB
# pyright    ------------------------------ 4.25 MiB/5.42 MiB
# onnxruntime ------------------------------ 15.54 MiB/15.63 MiB
# uv         ------------------------------ 18.25 MiB/18.42 MiB
# lancedb    ------------------------------ 22.26 MiB/33.34 MiB
# pyarrow    ------------------------------ 21.05 MiB/40.84 MiB
# ⠹ Preparing packages... (198/204) 20.43 MiB/43.79 MiB
# pyright    ------------------------------ 4.26 MiB/5.42 MiB
# onnxruntime ------------------------------ 15.54 MiB/15.63 MiB
# uv         ------------------------------ 18.25 MiB/18.42 MiB
# lancedb    ------------------------------ 22.97 MiB/33.34 MiB
# pyarrow    ------------------------------ 21.05 MiB/40.84 MiB
# ⠸ Preparing packages... (198/204) 20.43 MiB/43.79 MiB
# pyright    ------------------------------ 4.56 MiB/5.42 MiB
# onnxruntime ------------------------------ 15.54 MiB/15.63 MiB
# uv         ------------------------------ 18.25 MiB/18.42 MiB
# lancedb    ------------------------------ 23.74 MiB/33.34 MiB
# pyarrow    ------------------------------ 21.05 MiB/40.84 MiB
# ⠸ Preparing packages... (198/204) 20.43 MiB/43.79 MiB
# onnxruntime ------------------------------ 15.54 MiB/15.63 MiB
# uv         ------------------------------ 18.25 MiB/18.42 MiB
# lancedb    ------------------------------ 23.90 MiB/33.34 MiB
# pyarrow    ------------------------------ 21.05 MiB/40.84 MiB
# ⠸ Preparing packages... (198/204) 20.43 MiB/43.79 MiB
# onnxruntime ------------------------------ 15.54 MiB/15.63 MiB
# uv         ------------------------------ 18.25 MiB/18.42 MiB
# lancedb    ------------------------------ 25.81 MiB/33.34 MiB
# pyarrow    ------------------------------ 21.05 MiB/40.84 MiB
# ⠸ Preparing packages... (198/204) 20.43 MiB/43.79 MiB
# onnxruntime ------------------------------ 15.56 MiB/15.63 MiB
# uv         ------------------------------ 18.25 MiB/18.42 MiB
# lancedb    ------------------------------ 26.57 MiB/33.34 MiB
# pyarrow    ------------------------------ 23.03 MiB/40.84 MiB
# ⠸ Preparing packages... (198/204) 22.36 MiB/43.79 MiB
# onnxruntime ------------------------------ 15.56 MiB/15.63 MiB
# uv         ------------------------------ 18.25 MiB/18.42 MiB
# lancedb    ------------------------------ 28.65 MiB/33.34 MiB
# pyarrow    ------------------------------ 24.12 MiB/40.84 MiB
# ⠼ Preparing packages... (199/204) 23.99 MiB/43.79 MiB
# uv         ------------------------------ 18.25 MiB/18.42 MiB
# lancedb    ------------------------------ 29.69 MiB/33.34 MiB
# pyarrow    ------------------------------ 24.18 MiB/40.84 MiB
# ⠼ Preparing packages... (199/204) 25.16 MiB/43.79 MiB
# uv         ------------------------------ 18.25 MiB/18.42 MiB
# lancedb    ------------------------------ 30.14 MiB/33.34 MiB
# pyarrow    ------------------------------ 24.24 MiB/40.84 MiB
# ⠼ Preparing packages... (199/204) 27.03 MiB/43.79 MiB
# lancedb    ------------------------------ 30.14 MiB/33.34 MiB
# pyarrow    ------------------------------ 24.48 MiB/40.84 MiB
# ⠼ Preparing packages... (199/204) 28.21 MiB/43.79 MiB
# lancedb    ------------------------------ 30.14 MiB/33.34 MiB
# pyarrow    ------------------------------ 24.76 MiB/40.84 MiB
# ⠴ Preparing packages... (201/204) 29.54 MiB/43.79 MiB
# lancedb    ------------------------------ 30.14 MiB/33.34 MiB
# pyarrow    ------------------------------ 25.16 MiB/40.84 MiB
# ⠴ Preparing packages... (201/204) 29.54 MiB/43.79 MiB
# lancedb    ------------------------------ 30.14 MiB/33.34 MiB
# pyarrow    ------------------------------ 25.16 MiB/40.84 MiB
# ⠴ Preparing packages... (201/204) 29.56 MiB/43.79 MiB
# lancedb    ------------------------------ 30.14 MiB/33.34 MiB
# pyarrow    ------------------------------ 25.16 MiB/40.84 MiB
# ⠴ Preparing packages... (201/204) 29.57 MiB/43.79 MiB
# lancedb    ------------------------------ 30.14 MiB/33.34 MiB
# pyarrow    ------------------------------ 25.16 MiB/40.84 MiB
# ⠴ Preparing packages... (201/204) 29.59 MiB/43.79 MiB
# lancedb    ------------------------------ 31.95 MiB/33.34 MiB
# pyarrow    ------------------------------ 25.55 MiB/40.84 MiB
# ⠦ Preparing packages... (201/204) 31.91 MiB/43.79 MiB
# lancedb    ------------------------------ 33.34 MiB/33.34 MiB
# pyarrow    ------------------------------ 28.11 MiB/40.84 MiB
# ⠧ Preparing packages... (201/204) 32.68 MiB/43.79 MiB
# lancedb    ------------------------------ 33.34 MiB/33.34 MiB
# pyarrow    ------------------------------ 28.11 MiB/40.84 MiB
# ⠧ Preparing packages... (201/204) 32.68 MiB/43.79 MiB
# pyarrow    ------------------------------ 28.11 MiB/40.84 MiB
# ⠧ Preparing packages... (201/204) 32.68 MiB/43.79 MiB
# pyarrow    ------------------------------ 28.14 MiB/40.84 MiB
# ⠧ Preparing packages... (201/204) 32.68 MiB/43.79 MiB
# pyarrow    ------------------------------ 28.16 MiB/40.84 MiB
# ⠧ Preparing packages... (201/204) 32.68 MiB/43.79 MiB
# pyarrow    ------------------------------ 28.17 MiB/40.84 MiB
# ⠧ Preparing packages... (201/204) 32.68 MiB/43.79 MiB
# pyarrow    ------------------------------ 30.45 MiB/40.84 MiB
# ⠧ Preparing packages... (201/204) 32.68 MiB/43.79 MiB
# pyarrow    ------------------------------ 34.94 MiB/40.84 MiB
# ⠧ Preparing packages... (201/204) 32.68 MiB/43.79 MiB
# pyarrow    ------------------------------ 39.03 MiB/40.84 MiB
# ⠧ Preparing packages... (201/204) 32.68 MiB/43.79 MiB
# pyarrow    ------------------------------ 39.88 MiB/40.84 MiB
# ⠇ Preparing packages... (202/204) 33.85 MiB/43.79 MiB
# pyarrow    ------------------------------ 40.59 MiB/40.84 MiB
# ⠇ Preparing packages... (202/204) 36.27 MiB/43.79 MiB
# ⠇ Preparing packages... (202/204) 36.93 MiB/43.79 MiB
# ⠋ Preparing packages... (203/204) 39.71 MiB/43.79 MiB
# ⠋ Preparing packages... (203/204) 39.97 MiB/43.79 MiB
# ⠋ Preparing packages... (203/204) 40.02 MiB/43.79 MiB
# ⠋ Preparing packages... (203/204) 40.63 MiB/43.79 MiB
# Prepared 204 packages in 7.12s
# Installed 204 packages in 361ms
#  + aiohappyeyeballs==2.6.1
#  + aiohttp==3.12.15
#  + aiosignal==1.4.0
#  + alembic==1.16.4
#  + annotated-types==0.7.0
#  + anthropic==0.64.0
#  + anyio==4.10.0
#  + appdirs==1.4.4
#  + asgiref==3.9.1
#  + asttokens==3.0.0
#  + attrs==25.3.0
#  + backoff==2.2.1
#  + bcrypt==4.3.0
#  + beautifulsoup4==4.13.4
#  + blinker==1.9.0
#  + browserbase==1.4.0
#  + build==1.3.0
#  + cachetools==5.5.2
#  + certifi==2025.8.3
#  + cffi==1.17.1
#  + charset-normalizer==3.4.3
#  + chroma-hnswlib==0.7.6
#  + chromadb==0.5.23
#  + click==8.2.1
#  + cohere==5.17.0
#  + coloredlogs==15.0.1
#  + crewai==0.159.0
#  + crewai-tools==0.62.0
#  + cryptography==45.0.6
#  + dataclasses-json==0.6.7
#  + decorator==5.2.1
#  + deprecation==2.1.0
#  + diskcache==5.6.3
#  + distro==1.9.0
#  + docker==7.1.0
#  + docstring-parser==0.17.0
#  + durationpy==0.10
#  + embedchain==0.1.128
#  + et-xmlfile==2.0.0
#  + executing==2.2.0
#  + fastapi==0.116.1
#  + fastavro==1.12.0
#  + filelock==3.19.1
#  + flatbuffers==25.2.10
#  + frozenlist==1.7.0
#  + fsspec==2025.7.0
#  + google-auth==2.40.3
#  + googleapis-common-protos==1.70.0
#  + gptcache==0.1.44
#  + greenlet==3.2.4
#  + grpcio==1.74.0
#  + h11==0.16.0
#  + h2==4.2.0
#  + hf-xet==1.1.7
#  + hpack==4.1.0
#  + httpcore==1.0.9
#  + httptools==0.6.4
#  + httpx==0.28.1
#  + httpx-sse==0.4.0
#  + huggingface-hub==0.34.4
#  + humanfriendly==10.0
#  + hyperframe==6.1.0
#  + idna==3.10
#  + importlib-metadata==8.7.0
#  + importlib-resources==6.5.2
#  + instructor==1.10.0
#  + ipython==8.37.0
#  + jedi==0.19.2
#  + jinja2==3.1.6
#  + jiter==0.10.0
#  + json-repair==0.25.2
#  + json5==0.12.1
#  + jsonpatch==1.33
#  + jsonpickle==4.1.1
#  + jsonpointer==3.0.0
#  + jsonref==1.1.0
#  + jsonschema==4.25.0
#  + jsonschema-specifications==2025.4.1
#  + kubernetes==33.1.0
#  + lancedb==0.24.3
#  + langchain==0.3.27
#  + langchain-cohere==0.3.5
#  + langchain-community==0.3.27
#  + langchain-core==0.3.74
#  + langchain-experimental==0.3.4
#  + langchain-openai==0.2.14
#  + langchain-text-splitters==0.3.9
#  + langsmith==0.3.45
#  + litellm==1.74.9
#  + mako==1.3.10
#  + markdown-it-py==4.0.0
#  + markupsafe==3.0.2
#  + marshmallow==3.26.1
#  + matplotlib-inline==0.1.7
#  + mdurl==0.1.2
#  + mem0ai==0.1.115
#  + mmh3==5.2.0
#  + monotonic==1.6
#  + mpmath==1.3.0
#  + multidict==6.6.4
#  + mypy-extensions==1.1.0
#  + networkx==3.4.2
#  + new-project==0.1.0 (from file:///home/jovyan/work/L13/new_project)
#  + nodeenv==1.9.1
#  + numpy==2.2.6
#  + oauthlib==3.3.1
#  + onnxruntime==1.22.0
#  + openai==1.99.9
#  + openpyxl==3.1.5
#  + opentelemetry-api==1.36.0
#  + opentelemetry-exporter-otlp-proto-common==1.36.0
#  + opentelemetry-exporter-otlp-proto-grpc==1.36.0
#  + opentelemetry-exporter-otlp-proto-http==1.36.0
#  + opentelemetry-instrumentation==0.57b0
#  + opentelemetry-instrumentation-asgi==0.57b0
#  + opentelemetry-instrumentation-fastapi==0.57b0
#  + opentelemetry-proto==1.36.0
#  + opentelemetry-sdk==1.36.0
#  + opentelemetry-semantic-conventions==0.57b0
#  + opentelemetry-util-http==0.57b0
#  + orjson==3.11.2
#  + overrides==7.7.0
#  + packaging==25.0
#  + pandas==2.3.1
#  + parso==0.8.4
#  + pdfminer-six==20250506
#  + pdfplumber==0.11.7
#  + pexpect==4.9.0
#  + pillow==11.3.0
#  + playwright==1.54.0
#  + portalocker==2.7.0
#  + posthog==3.25.0
#  + prompt-toolkit==3.0.51
#  + propcache==0.3.2
#  + protobuf==6.32.0
#  + ptyprocess==0.7.0
#  + pure-eval==0.2.3
#  + pyarrow==21.0.0
#  + pyasn1==0.6.1
#  + pyasn1-modules==0.4.2
#  + pycparser==2.22
#  + pydantic==2.11.7
#  + pydantic-core==2.33.2
#  + pydantic-settings==2.10.1
#  + pyee==13.0.0
#  + pygments==2.19.2
#  + pyjwt==2.10.1
#  + pypdf==5.9.0
#  + pypdfium2==4.30.0
#  + pypika==0.48.9
#  + pyproject-hooks==1.2.0
#  + pyright==1.1.403
#  + pysbd==0.3.4
#  + python-dateutil==2.9.0.post0
#  + python-dotenv==1.1.1
#  + pytube==15.0.0
#  + pytz==2025.2
#  + pyvis==0.3.2
#  + pyyaml==6.0.2
#  + qdrant-client==1.15.1
#  + referencing==0.36.2
#  + regex==2025.7.34
#  + requests==2.32.4
#  + requests-oauthlib==2.0.0
#  + requests-toolbelt==1.0.0
#  + rich==13.9.4
#  + rpds-py==0.27.0
#  + rsa==4.9.1
#  + schema==0.7.7
#  + shellingham==1.5.4
#  + six==1.17.0
#  + sniffio==1.3.1
#  + soupsieve==2.7
#  + sqlalchemy==2.0.43
#  + stack-data==0.6.3
#  + stagehand==0.5.0
#  + starlette==0.47.2
#  + sympy==1.14.0
#  + tabulate==0.9.0
#  + tenacity==9.1.2
#  + tiktoken==0.11.0
#  + tokenizers==0.20.3
#  + tomli==2.2.1
#  + tomli-w==1.2.0
#  + tqdm==4.67.1
#  + traitlets==5.14.3
#  + typer==0.16.0
#  + types-requests==2.32.4.20250809
#  + typing-extensions==4.14.1
#  + typing-inspect==0.9.0
#  + typing-inspection==0.4.1
#  + tzdata==2025.2
#  + urllib3==2.5.0
#  + uv==0.8.11
#  + uvicorn==0.35.0
#  + uvloop==0.21.0
#  + watchfiles==1.1.0
#  + wcwidth==0.2.13
#  + websocket-client==1.8.0
#  + websockets==15.0.1
#  + wrapt==1.17.3
#  + yarl==1.20.1
#  + zipp==3.23.0
#  + zstandard==0.23.0

# %% [markdown]
# ## Setting Environment Variables

# %%
! cat new_project/.env
# Out:
# OPENAI_API_KEY=YOUR_API_KEY_HERE

# %% [markdown]
# ## Running the Crew

# %%
! cd new_project && crewai run
# Out:
# Running the Crew
# ╭─────────────────────────── Crew Execution Started ───────────────────────────╮
# │                                                                              │
# │  Crew Execution Started                                                      │
# │  Name: crew                                                                  │
# │  ID: 97443310-af24-4d8f-ac33-6218f02000ff                                    │
# │  Tool Args:                                                                  │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# └── 📋 Task: 4b7771cf-fdca-4799-a3f5-9d976ad505a8
#     Status: Executing Task...
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: AI LLMs Senior Data Researcher                                       │
# │                                                                              │
# │  Task: Conduct a thorough research about AI LLMs Make sure you find any      │
# │  interesting and relevant information given the current year is 2024.        │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# └── 📋 Task: 4b7771cf-fdca-4799-a3f5-9d976ad505a8
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: 4b7771cf-fdca-4799-a3f5-9d976ad505a8
# 🚀 Crew: crew
# └── 📋 Task: 4b7771cf-fdca-4799-a3f5-9d976ad505a8
#     Status: Executing Task...
# ╭─────────────────────────── ✅ Agent Final Answer ────────────────────────────╮
# │                                                                              │
# │  Agent: AI LLMs Senior Data Researcher                                       │
# │                                                                              │
# │  Final Answer:                                                               │
# │  1. **Transformers and Beyond**: As of 2024, models based on the             │
# │  transformer architecture continue to dominate the landscape of AI LLMs,     │
# │  with innovations focusing on improving efficiency and reducing              │
# │  computational costs through techniques like sparse transformers and         │
# │  mix-and-match architectures.                                                │
# │                                                                              │
# │  2. **Multimodal Capabilities**: The integration of text with other          │
# │  modalities, such as images and audio, is accelerating, with models like     │
# │  OpenAI's GPT-5 exhibiting sophisticated understanding across various types  │
# │  of data, enabling capabilities like generating images from text             │
# │  descriptions or generating text based on video content.                     │
# │                                                                              │
# │  3. **Selective Memory Architecture**: New architectures are emerging that   │
# │  utilize selective memory, allowing AI LLMs to recall relevant information   │
# │  from a vast dataset efficiently without storing all data, enhancing         │
# │  performance in knowledge-intensive tasks and improving contextuality in     │
# │  responses.                                                                  │
# │                                                                              │
# │  4. **Ethical AI and Regulation**: There is a growing focus on ethical AI    │
# │  development, with regulatory bodies around the world drafting guidelines    │
# │  to ensure the responsible use of AI LLM technologies, emphasizing           │
# │  transparency, fairness, and accountability.                                 │
# │                                                                              │
# │  5. **Low-Resource Language Support**: A major advancement includes the      │
# │  development of AI LLMs capable of supporting low-resource languages, which  │
# │  broadens accessibility and inclusion by providing multilingual              │
# │  capabilities and better representation of diverse cultures.                 │
# │                                                                              │
# │  6. **Personalization and User Adaptation**: AI LLMs are increasingly        │
# │  incorporating personalization features, adapting to individual user         │
# │  preferences and communication styles, thus enhancing user experience and    │
# │  engagement through more tailored interactions.                              │
# │                                                                              │
# │  7. **Energy-Efficient Training Techniques**: Research is focusing on        │
# │  energy-efficient training methods, including quantization and pruning,      │
# │  that reduce the carbon footprint associated with training massive language  │
# │  models, addressing growing concerns about sustainability in AI              │
# │  development.                                                                │
# │                                                                              │
# │  8. **Enhanced Interpretability**: Techniques that foster interpretability   │
# │  of LLMs are on the rise, allowing users to better understand model          │
# │  decisions and outputs, which is crucial for applications in sensitive       │
# │  areas like healthcare and finance.                                          │
# │                                                                              │
# │  9. **Federated Learning**: The utilization of federated learning            │
# │  techniques is gaining momentum, which enables AI LLMs to learn from         │
# │  decentralized data sources while preserving user privacy, significantly     │
# │  enhancing collaborative training processes without compromising sensitive   │
# │  information.                                                                │
# │                                                                              │
# │  10. **AI-Assisted Code Generation**: The integration of AI LLMs in          │
# │  software development is evolving, with tools like OpenAI's GitHub Copilot   │
# │  using advanced LLMs to assist developers in coding tasks, thereby speeding  │
# │  up development cycles and reducing bugs through intelligent suggestions.    │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# └── 📋 Task: 4b7771cf-fdca-4799-a3f5-9d976ad505a8
#     Assigned to: AI LLMs Senior Data Researcher
#
#     Status: ✅ Completed
# ╭────────────────────────────── Task Completion ───────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name: 4b7771cf-fdca-4799-a3f5-9d976ad505a8                                  │
# │  Agent: AI LLMs Senior Data Researcher                                       │
# │                                                                              │
# │  Tool Args:                                                                  │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# 🚀 Crew: crew
# ├── 📋 Task: 4b7771cf-fdca-4799-a3f5-9d976ad505a8
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: 846d8f5d-67b1-418c-a252-4423d47d73cd
#     Status: Executing Task...
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: AI LLMs Reporting Analyst                                            │
# │                                                                              │
# │  Task: Review the context you got and expand each topic into a full section  │
# │  for a report. Make sure the report is detailed and contains any and all     │
# │  relevant information.                                                       │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# ├── 📋 Task: 4b7771cf-fdca-4799-a3f5-9d976ad505a8
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: 846d8f5d-67b1-418c-a252-4423d47d73cd
# 🚀 Crew: crew
# ├── 📋 Task: 4b7771cf-fdca-4799-a3f5-9d976ad505a8
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: 846d8f5d-67b1-418c-a252-4423d47d73cd
#     Status: Executing Task...
# ╭─────────────────────────── ✅ Agent Final Answer ────────────────────────────╮
# │                                                                              │
# │  Agent: AI LLMs Reporting Analyst                                            │
# │                                                                              │
# │  Final Answer:                                                               │
# │  # Comprehensive Report on the Current State and Future Trends of AI LLMs    │
# │                                                                              │
# │  ## 1. Transformers and Beyond                                               │
# │  As of 2024, the landscape of AI Language Learning Models (LLMs) is          │
# │  predominantly shaped by the transformer architecture, which remains the     │
# │  backbone of modern AI models. The focus has shifted towards improving the   │
# │  efficiency of these models while simultaneously reducing their              │
# │  computational costs. Innovations such as sparse transformers, which         │
# │  leverage techniques to ignore less relevant data, and mix-and-match         │
# │  architectures, allow for optimized model configurations wherein different   │
# │  components can be combined for specialized tasks. These advancements not    │
# │  only enhance performance but also democratize access to powerful AI tools   │
# │  by making them more resource-efficient and accessible to organizations      │
# │  with lower computational capabilities.                                      │
# │                                                                              │
# │  ## 2. Multimodal Capabilities                                               │
# │  The integration of multiple modalities—particularly the combination of      │
# │  text, images, and audio—is advancing rapidly, exemplified by OpenAI's       │
# │  GPT-5 model. This multimodal capability allows for an understanding that    │
# │  transcends traditional text-based processing, enabling AI systems to        │
# │  generate images directly from text descriptions and conversely, interpret   │
# │  and analyze video content to produce corresponding textual data. Such       │
# │  advancements open up new applications in fields like digital content        │
# │  creation, advertising, and education, where diverse inputs can be           │
# │  leveraged for richer user experiences and more interactive products.        │
# │                                                                              │
# │  ## 3. Selective Memory Architecture                                         │
# │  Emerging architectures that incorporate selective memory are paving the     │
# │  way for LLMs to enhance their performance in knowledge-intensive tasks. By  │
# │  efficiently recalling salient information from extensive datasets without   │
# │  necessitating the storage of all underlying data, these models can provide  │
# │  more contextual and relevant responses. This is particularly significant    │
# │  in domains requiring deep contextual understanding, such as legal research  │
# │  or academic writing, where the ability to leverage specific knowledge       │
# │  without cumbersome data overhead can greatly improve work efficiency and    │
# │  accuracy.                                                                   │
# │                                                                              │
# │  ## 4. Ethical AI and Regulation                                             │
# │  The dialogue around ethical AI development has gained significant           │
# │  traction, prompting regulatory bodies globally to draft comprehensive       │
# │  guidelines to ensure the responsible use of AI LLM technologies. These      │
# │  guidelines emphasize key principles such as transparency, fairness,         │
# │  accountability, and inclusivity. The focus is on establishing frameworks    │
# │  that prevent biases in AI outputs, ensure data privacy, and address the     │
# │  societal impact of AI technologies. By fostering ethical considerations in  │
# │  model development and deployment, stakeholders can better align AI          │
# │  advancements with societal values and public expectations.                  │
# │                                                                              │
# │  ## 5. Low-Resource Language Support                                         │
# │  Recent advancements have led to the development of AI LLMs that support     │
# │  low-resource languages, significantly enhancing accessibility and           │
# │  representation for speakers of these languages. By implementing             │
# │  multilingual capabilities, these models increase inclusion and foster a     │
# │  richer diversity of cultural expression in the digital space. This is       │
# │  crucial for ensuring that non-English speaking populations are not          │
# │  marginalized in the AI revolution, thereby promoting equal opportunities    │
# │  for communication and content creation across language barriers.            │
# │                                                                              │
# │  ## 6. Personalization and User Adaptation                                   │
# │  AI LLMs are increasingly being designed with personalization features that  │
# │  adapt to individual user preferences and communication styles. By           │
# │  integrating user data and feedback, these models can tailor interactions    │
# │  to align more closely with user expectations, which enhances engagement     │
# │  and satisfaction. Personalized AI experiences are becoming critical in      │
# │  applications ranging from customer service chatbots to educational tools,   │
# │  where the ability to connect with users on a personal level can             │
# │  significantly enhance learning outcomes and user experience.                │
# │                                                                              │
# │  ## 7. Energy-Efficient Training Techniques                                  │
# │  As concerns about the environmental impact of AI training escalates,        │
# │  research has pivoted towards developing energy-efficient training           │
# │  techniques. Methods such as quantization and pruning are being explored to  │
# │  minimize the carbon footprint associated with training large models. These  │
# │  techniques not only streamline the computational requirements but also      │
# │  promote sustainable AI development practices, allowing organizations to     │
# │  balance technological advancement with ecological responsibility. The       │
# │  shift towards environmentally conscious AI practices is crucial for         │
# │  establishing a sustainable future for technology.                           │
# │                                                                              │
# │  ## 8. Enhanced Interpretability                                             │
# │  The enhancement of interpretability in AI LLMs is increasingly recognized   │
# │  as vital, particularly for applications in sensitive and critical fields    │
# │  such as healthcare and finance. New techniques are being implemented to     │
# │  help users comprehend the rationale behind model decisions and outputs. By  │
# │  improving transparency into model behavior, stakeholders can foster trust   │
# │  in AI systems, ensuring that these technologies are used ethically and      │
# │  effectively in high-stakes environments where understanding the reasoning   │
# │  behind AI-generated outcomes is essential.                                  │
# │                                                                              │
# │  ## 9. Federated Learning                                                    │
# │  Federated learning is gaining momentum as a robust approach to AI training  │
# │  that allows LLMs to learn from decentralized data sources while preserving  │
# │  user privacy. This cutting-edge technique enables collaborative training    │
# │  of models across multiple devices without the need to centralize sensitive  │
# │  data. As privacy concerns heighten, federated learning presents an          │
# │  innovative solution that not only enhances the performance of AI systems    │
# │  through diverse data inputs but also adheres to stringent data protection   │
# │  standards. It represents a significant shift towards more                   │
# │  privacy-conscious AI development.                                           │
# │                                                                              │
# │  ## 10. AI-Assisted Code Generation                                          │
# │  The integration of AI LLMs in the software development lifecycle has        │
# │  evolved considerably, evidenced by tools like OpenAI's GitHub Copilot.      │
# │  These tools leverage advanced language models to assist developers in       │
# │  various coding tasks, effectively speeding up development cycles and        │
# │  reducing errors through intelligent suggestions and completions. As         │
# │  AI-assisted code generation becomes more prevalent, it transforms the way   │
# │  programming is approached, enabling developers to focus on higher-level     │
# │  problem-solving while AI handles more straightforward coding tasks. This    │
# │  synergy between human expertise and AI efficiency has the potential to      │
# │  revolutionize software development, driving innovation and enhancing        │
# │  productivity.                                                               │
# │                                                                              │
# │  By synthesizing these diverse threads of research and development, we can   │
# │  see a clear trajectory towards more efficient, ethical, and inclusive AI    │
# │  models, poised to address both current challenges and future opportunities  │
# │  in the AI landscape.                                                        │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# ├── 📋 Task: 4b7771cf-fdca-4799-a3f5-9d976ad505a8
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: 846d8f5d-67b1-418c-a252-4423d47d73cd
#     Assigned to: AI LLMs Reporting Analyst
#
#     Status: ✅ Completed
# ╭────────────────────────────── Task Completion ───────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name: 846d8f5d-67b1-418c-a252-4423d47d73cd                                  │
# │  Agent: AI LLMs Reporting Analyst                                            │
# │                                                                              │
# │  Tool Args:                                                                  │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── Crew Completion ───────────────────────────────╮
# │                                                                              │
# │  Crew Execution Completed                                                    │
# │  Name: crew                                                                  │
# │  ID: 97443310-af24-4d8f-ac33-6218f02000ff                                    │
# │  Tool Args:                                                                  │
# │  Final Output: # Comprehensive Report on the Current State and Future        │
# │  Trends of AI LLMs                                                           │
# │                                                                              │
# │  ## 1. Transformers and Beyond                                               │
# │  As of 2024, the landscape of AI Language Learning Models (LLMs) is          │
# │  predominantly shaped by the transformer architecture, which remains the     │
# │  backbone of modern AI models. The focus has shifted towards improving the   │
# │  efficiency of these models while simultaneously reducing their              │
# │  computational costs. Innovations such as sparse transformers, which         │
# │  leverage techniques to ignore less relevant data, and mix-and-match         │
# │  architectures, allow for optimized model configurations wherein different   │
# │  components can be combined for specialized tasks. These advancements not    │
# │  only enhance performance but also democratize access to powerful AI tools   │
# │  by making them more resource-efficient and accessible to organizations      │
# │  with lower computational capabilities.                                      │
# │                                                                              │
# │  ## 2. Multimodal Capabilities                                               │
# │  The integration of multiple modalities—particularly the combination of      │
# │  text, images, and audio—is advancing rapidly, exemplified by OpenAI's       │
# │  GPT-5 model. This multimodal capability allows for an understanding that    │
# │  transcends traditional text-based processing, enabling AI systems to        │
# │  generate images directly from text descriptions and conversely, interpret   │
# │  and analyze video content to produce corresponding textual data. Such       │
# │  advancements open up new applications in fields like digital content        │
# │  creation, advertising, and education, where diverse inputs can be           │
# │  leveraged for richer user experiences and more interactive products.        │
# │                                                                              │
# │  ## 3. Selective Memory Architecture                                         │
# │  Emerging architectures that incorporate selective memory are paving the     │
# │  way for LLMs to enhance their performance in knowledge-intensive tasks. By  │
# │  efficiently recalling salient information from extensive datasets without   │
# │  necessitating the storage of all underlying data, these models can provide  │
# │  more contextual and relevant responses. This is particularly significant    │
# │  in domains requiring deep contextual understanding, such as legal research  │
# │  or academic writing, where the ability to leverage specific knowledge       │
# │  without cumbersome data overhead can greatly improve work efficiency and    │
# │  accuracy.                                                                   │
# │                                                                              │
# │  ## 4. Ethical AI and Regulation                                             │
# │  The dialogue around ethical AI development has gained significant           │
# │  traction, prompting regulatory bodies globally to draft comprehensive       │
# │  guidelines to ensure the responsible use of AI LLM technologies. These      │
# │  guidelines emphasize key principles such as transparency, fairness,         │
# │  accountability, and inclusivity. The focus is on establishing frameworks    │
# │  that prevent biases in AI outputs, ensure data privacy, and address the     │
# │  societal impact of AI technologies. By fostering ethical considerations in  │
# │  model development and deployment, stakeholders can better align AI          │
# │  advancements with societal values and public expectations.                  │
# │                                                                              │
# │  ## 5. Low-Resource Language Support                                         │
# │  Recent advancements have led to the development of AI LLMs that support     │
# │  low-resource languages, significantly enhancing accessibility and           │
# │  representation for speakers of these languages. By implementing             │
# │  multilingual capabilities, these models increase inclusion and foster a     │
# │  richer diversity of cultural expression in the digital space. This is       │
# │  crucial for ensuring that non-English speaking populations are not          │
# │  marginalized in the AI revolution, thereby promoting equal opportunities    │
# │  for communication and content creation across language barriers.            │
# │                                                                              │
# │  ## 6. Personalization and User Adaptation                                   │
# │  AI LLMs are increasingly being designed with personalization features that  │
# │  adapt to individual user preferences and communication styles. By           │
# │  integrating user data and feedback, these models can tailor interactions    │
# │  to align more closely with user expectations, which enhances engagement     │
# │  and satisfaction. Personalized AI experiences are becoming critical in      │
# │  applications ranging from customer service chatbots to educational tools,   │
# │  where the ability to connect with users on a personal level can             │
# │  significantly enhance learning outcomes and user experience.                │
# │                                                                              │
# │  ## 7. Energy-Efficient Training Techniques                                  │
# │  As concerns about the environmental impact of AI training escalates,        │
# │  research has pivoted towards developing energy-efficient training           │
# │  techniques. Methods such as quantization and pruning are being explored to  │
# │  minimize the carbon footprint associated with training large models. These  │
# │  techniques not only streamline the computational requirements but also      │
# │  promote sustainable AI development practices, allowing organizations to     │
# │  balance technological advancement with ecological responsibility. The       │
# │  shift towards environmentally conscious AI practices is crucial for         │
# │  establishing a sustainable future for technology.                           │
# │                                                                              │
# │  ## 8. Enhanced Interpretability                                             │
# │  The enhancement of interpretability in AI LLMs is increasingly recognized   │
# │  as vital, particularly for applications in sensitive and critical fields    │
# │  such as healthcare and finance. New techniques are being implemented to     │
# │  help users comprehend the rationale behind model decisions and outputs. By  │
# │  improving transparency into model behavior, stakeholders can foster trust   │
# │  in AI systems, ensuring that these technologies are used ethically and      │
# │  effectively in high-stakes environments where understanding the reasoning   │
# │  behind AI-generated outcomes is essential.                                  │
# │                                                                              │
# │  ## 9. Federated Learning                                                    │
# │  Federated learning is gaining momentum as a robust approach to AI training  │
# │  that allows LLMs to learn from decentralized data sources while preserving  │
# │  user privacy. This cutting-edge technique enables collaborative training    │
# │  of models across multiple devices without the need to centralize sensitive  │
# │  data. As privacy concerns heighten, federated learning presents an          │
# │  innovative solution that not only enhances the performance of AI systems    │
# │  through diverse data inputs but also adheres to stringent data protection   │
# │  standards. It represents a significant shift towards more                   │
# │  privacy-conscious AI development.                                           │
# │                                                                              │
# │  ## 10. AI-Assisted Code Generation                                          │
# │  The integration of AI LLMs in the software development lifecycle has        │
# │  evolved considerably, evidenced by tools like OpenAI's GitHub Copilot.      │
# │  These tools leverage advanced language models to assist developers in       │
# │  various coding tasks, effectively speeding up development cycles and        │
# │  reducing errors through intelligent suggestions and completions. As         │
# │  AI-assisted code generation becomes more prevalent, it transforms the way   │
# │  programming is approached, enabling developers to focus on higher-level     │
# │  problem-solving while AI handles more straightforward coding tasks. This    │
# │  synergy between human expertise and AI efficiency has the potential to      │
# │  revolutionize software development, driving innovation and enhancing        │
# │  productivity.                                                               │
# │                                                                              │
# │  By synthesizing these diverse threads of research and development, we can   │
# │  see a clear trajectory towards more efficient, ethical, and inclusive AI    │
# │  models, poised to address both current challenges and future opportunities  │
# │  in the AI landscape.                                                        │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# ## Flows CLI - Command Line Interface

# %%
! crewai create flow new_flow
# Out:
# Creating flow new_flow...
# Flow new_flow created successfully!

# %%
! ls -1 new_flow
# Out:
# README.md
# pyproject.toml
# src
# tests

# %%
! ls -1 new_flow/src/new_flow/
# Out:
# __init__.py
# crews
# main.py
# tools
